# %% [markdown]
# ## CNN - Alexnet

# %%
import os
import pandas as pd
import numpy as np
import time

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim


import matplotlib.pyplot as plt

from torchvision import models
from torchinfo import summary
from torchvision import datasets, transforms
from torch.utils.data import random_split, DataLoader, Dataset
from torchmetrics.classification import MulticlassConfusionMatrix, MulticlassPrecision, MulticlassRecall, MulticlassF1Score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ### checking if Gpu were recognized

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("PyTorch is using GPU!")
    print(torch.cuda.get_device_name(0)) #prints the name of the GPU.
else:
    device = torch.device("cpu")
    print("PyTorch is using CPU.")
# Out:
# PyTorch is using GPU!
# NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ### Training dataset

# %%
os.path.realpath('data/p2-mammography')
# Out:
# '/home/viviane/projects/breast-cancer-v2/notebooks/data/p2-mammography'

# %%
path = os.path.realpath('data/p2-mammography')
list_path = path.split('/')
list_path.remove('breast-cancer-v2')
list_path.remove('notebooks')
path_train = os.path.join('/'.join(list_path), 'train_augmented')
path_train
# Out:
# '/home/viviane/projects/data/p2-mammography/train_augmented'

# %%
dataset = datasets.ImageFolder(
    root=path_train, 
    transform=transforms.ToTensor()
)
classes = dataset.classes
print(classes)
# Out:
# ['Density1_Benign', 'Density1_Malignant', 'Density2_Benign', 'Density2_Malignant', 'Density3_Benign', 'Density3_Malignant', 'Density4_Benign', 'Density4_Malignant']

# %% [markdown]
# ### Test dataset

# %%
path = os.path.realpath('data/p2-mammography')
list_path = path.split('/')
list_path.remove('breast-cancer-v2')
list_path.remove('notebooks')
path_test = os.path.join('/'.join(list_path), 'test_augmented')
path_test
# Out:
# '/home/viviane/projects/data/p2-mammography/test_augmented'

# %%
train_dir = path_train
val_dir = path_test

# %% [markdown]
# # Preprocessing

# %%
IMAGE_SIZE = 227
BATCH_SIZE = 16

# %%
# Define data augmentation for the training dataset
train_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),                      
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]) # Normalization
])

# Define validation dataset - no augmentation, only resizing and normalization
test_transforms = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])


# split train_dataset and load
train_dataset = torchvision.datasets.ImageFolder(root=train_dir, transform=train_transforms)
test_dataset = torchvision.datasets.ImageFolder(root=val_dir, transform=test_transforms)

train_size = int(0.8 * len(train_dataset))  # 80% for training
val_size = len(train_dataset) - train_size  # Remaining for testing

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# Define loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)


print(f'Training samples: {len(train_dataset)}, , Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}')
# Out:
# Training samples: 7818, , Validation samples: 1955, Test samples: 1957

# %% [markdown]
# # Architecture

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 8

model = models.alexnet(weights=None) 
model.classifier[6] = nn.Linear(4096, num_classes)
model = model.to(device)

print(model)

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=8, bias=True)
#   )
# )

# %%
summary(model, input_size=(BATCH_SIZE, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# AlexNet                                  [16, 8]                   --
# ├─Sequential: 1-1                        [16, 256, 6, 6]           --
# │    └─Conv2d: 2-1                       [16, 64, 55, 55]          23,296
# │    └─ReLU: 2-2                         [16, 64, 55, 55]          --
# │    └─MaxPool2d: 2-3                    [16, 64, 27, 27]          --
# │    └─Conv2d: 2-4                       [16, 192, 27, 27]         307,392
# │    └─ReLU: 2-5                         [16, 192, 27, 27]         --
# │    └─MaxPool2d: 2-6                    [16, 192, 13, 13]         --
# │    └─Conv2d: 2-7                       [16, 384, 13, 13]         663,936
# │    └─ReLU: 2-8                         [16, 384, 13, 13]         --
# │    └─Conv2d: 2-9                       [16, 256, 13, 13]         884,992
# │    └─ReLU: 2-10                        [16, 256, 13, 13]         --
# │    └─Conv2d: 2-11                      [16, 256, 13, 13]         590,080
# │    └─ReLU: 2-12                        [16, 256, 13, 13]         --
# │    └─MaxPool2d: 2-13                   [16, 256, 6, 6]           --
# ├─AdaptiveAvgPool2d: 1-2                 [16, 256, 6, 6]           --
# ├─Sequential: 1-3                        [16, 8]                   --
# │    └─Dropout: 2-14                     [16, 9216]                --
# │    └─Linear: 2-15                      [16, 4096]                37,752,832
# │    └─ReLU: 2-16                        [16, 4096]                --
# │    └─Dropout: 2-17                     [16, 4096]                --
# │    └─Linear: 2-18                      [16, 4096]                16,781,312
# │    └─ReLU: 2-19                        [16, 4096]                --
# │    └─Linear: 2-20                      [16, 8]                   32,776
# ==========================================================================================
# Total params: 57,036,616
# Trainable params: 57,036,616
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 11.37
# ==========================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 63.13
# Params size (MB): 228.15
# Estimated Total Size (MB): 300.91
# ==========================================================================================

# %% [markdown]
# # Trainning

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    # Metrics
    confusion_matrix = MulticlassConfusionMatrix(num_classes=8)
    precision = MulticlassPrecision(num_classes=10, average='macro')
    recall = MulticlassRecall(num_classes=10, average='macro')
    f1_score = MulticlassF1Score(num_classes=10, average='macro')

    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0.0
        correct_train = 0
        total_train = 0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Clear gradients
            optimizer.zero_grad()

            # feed foward
            outputs = model(inputs)
            
            # Compute loss using cross entropy
            loss = criterion(outputs, labels)

            # backpropagation
            loss.backward()

            # Update weights
            optimizer.step()

            # Update results
            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (preds == labels).sum().item()

        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(100 * correct_train / total_train)

        # Evaluation part to print metrics for each epoch
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0

        all_preds = []
        all_labels = []

        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, preds = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (preds == labels).sum().item()

                # For metrics
                all_preds.append(preds.cpu())
                all_labels.append(labels.cpu())

        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(100 * correct_val / total_val)

        
        all_preds = torch.cat(all_preds)
        all_labels = torch.cat(all_labels)

        
        precision_value = precision(all_preds, all_labels)
        recall_value = recall(all_preds, all_labels)
        f1_value = f1_score(all_preds, all_labels)
        conf_matrix = confusion_matrix(all_preds, all_labels)

        
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print(f"Train Loss: {train_losses[-1]:.4f} | Train Acc: {train_accuracies[-1]:.2f}%")
        print(f"Val Loss: {val_losses[-1]:.4f} | Val Acc: {val_accuracies[-1]:.2f}%")
        print(f"Precision: {precision_value:.4f} | Recall: {recall_value:.4f} | F1 Score: {f1_value:.4f}\n")

    return train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix

# %%
t1 = time.time()
print(f"Using device: {device}")

train_losses, val_losses, train_accuracies, val_accuracies, conf_matrix = train_model(
    model, train_loader, val_loader, criterion, optimizer, num_epochs=50)

print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Using device: cuda
# Epoch 1/50
# Train Loss: 2.0805 | Train Acc: 12.24%
# Val Loss: 2.0761 | Val Acc: 12.48%
# Precision: 0.0312 | Recall: 0.1185 | F1 Score: 0.0493
#
# Epoch 2/50
# Train Loss: 2.0620 | Train Acc: 15.08%
# Val Loss: 2.0079 | Val Acc: 17.70%
# Precision: 0.1072 | Recall: 0.1871 | F1 Score: 0.1044
#
# Epoch 3/50
# Train Loss: 1.9703 | Train Acc: 20.90%
# Val Loss: 1.9629 | Val Acc: 19.85%
# Precision: 0.1461 | Recall: 0.2044 | F1 Score: 0.1324
#
# Epoch 4/50
# Train Loss: 1.9085 | Train Acc: 24.16%
# Val Loss: 1.8710 | Val Acc: 28.08%
# Precision: 0.2428 | Recall: 0.2759 | F1 Score: 0.2213
#
# Epoch 5/50
# Train Loss: 1.8568 | Train Acc: 26.26%
# Val Loss: 1.8608 | Val Acc: 28.39%
# Precision: 0.2716 | Recall: 0.2798 | F1 Score: 0.2204
#
# Epoch 6/50
# Train Loss: 1.8095 | Train Acc: 29.66%
# Val Loss: 1.7864 | Val Acc: 33.55%
# Precision: 0.3360 | Recall: 0.3299 | F1 Score: 0.2828
#
# Epoch 7/50
# Train Loss: 1.7605 | Train Acc: 31.38%
# Val Loss: 1.7450 | Val Acc: 31.30%
# Precision: 0.3246 | Recall: 0.3080 | F1 Score: 0.2719
#
# Epoch 8/50
# Train Loss: 1.7155 | Train Acc: 34.71%
# Val Loss: 1.7007 | Val Acc: 36.47%
# Precision: 0.3999 | Recall: 0.3705 | F1 Score: 0.3330
#
# Epoch 9/50
# Train Loss: 1.6747 | Train Acc: 37.44%
# Val Loss: 1.6156 | Val Acc: 42.97%
# Precision: 0.4240 | Recall: 0.4308 | F1 Score: 0.4183
#
# Epoch 10/50
# Train Loss: 1.6049 | Train Acc: 43.44%
# Val Loss: 1.5927 | Val Acc: 42.56%
# Precision: 0.4277 | Recall: 0.4284 | F1 Score: 0.4075
#
# Epoch 11/50
# Train Loss: 1.5431 | Train Acc: 46.19%
# Val Loss: 1.5459 | Val Acc: 48.08%
# Precision: 0.4585 | Recall: 0.4852 | F1 Score: 0.4499
#
# Epoch 12/50
# Train Loss: 1.4753 | Train Acc: 49.45%
# Val Loss: 1.4923 | Val Acc: 49.87%
# Precision: 0.5012 | Recall: 0.5020 | F1 Score: 0.4898
#
# Epoch 13/50
# Train Loss: 1.4125 | Train Acc: 53.43%
# Val Loss: 1.4563 | Val Acc: 49.26%
# Precision: 0.5115 | Recall: 0.4998 | F1 Score: 0.4838
#
# Epoch 14/50
# Train Loss: 1.3548 | Train Acc: 56.45%
# Val Loss: 1.3520 | Val Acc: 56.57%
# Precision: 0.5651 | Recall: 0.5713 | F1 Score: 0.5433
#
# Epoch 15/50
# Train Loss: 1.3117 | Train Acc: 58.38%
# Val Loss: 1.4335 | Val Acc: 51.41%
# Precision: 0.5171 | Recall: 0.5194 | F1 Score: 0.4910
#
# Epoch 16/50
# Train Loss: 1.2650 | Train Acc: 60.65%
# Val Loss: 1.3809 | Val Acc: 52.99%
# Precision: 0.5355 | Recall: 0.5349 | F1 Score: 0.5164
#
# Epoch 17/50
# Train Loss: 1.2238 | Train Acc: 63.20%
# Val Loss: 1.3704 | Val Acc: 55.81%
# Precision: 0.5645 | Recall: 0.5636 | F1 Score: 0.5517
#
# Epoch 18/50
# Train Loss: 1.1639 | Train Acc: 66.78%
# Val Loss: 1.3244 | Val Acc: 58.11%
# Precision: 0.5828 | Recall: 0.5886 | F1 Score: 0.5677
#
# Epoch 19/50
# Train Loss: 1.1333 | Train Acc: 68.27%
# Val Loss: 1.2960 | Val Acc: 59.69%
# Precision: 0.6040 | Recall: 0.6027 | F1 Score: 0.5860
#
# Epoch 20/50
# Train Loss: 1.0843 | Train Acc: 70.26%
# Val Loss: 1.2697 | Val Acc: 61.59%
# Precision: 0.6013 | Recall: 0.6213 | F1 Score: 0.6059
#
# Epoch 21/50
# Train Loss: 1.0454 | Train Acc: 73.01%
# Val Loss: 1.2501 | Val Acc: 63.17%
# Precision: 0.6164 | Recall: 0.6392 | F1 Score: 0.6167
#
# Epoch 22/50
# Train Loss: 1.0084 | Train Acc: 74.74%
# Val Loss: 1.2888 | Val Acc: 61.38%
# Precision: 0.6083 | Recall: 0.6208 | F1 Score: 0.6073
#
# Epoch 23/50
# Train Loss: 0.9657 | Train Acc: 77.50%
# Val Loss: 1.2672 | Val Acc: 62.35%
# Precision: 0.6161 | Recall: 0.6282 | F1 Score: 0.6204
#
# Epoch 24/50
# Train Loss: 0.9301 | Train Acc: 79.10%
# Val Loss: 1.2563 | Val Acc: 62.35%
# Precision: 0.6266 | Recall: 0.6291 | F1 Score: 0.6254
#
# Epoch 25/50
# Train Loss: 0.8942 | Train Acc: 80.99%
# Val Loss: 1.2552 | Val Acc: 64.50%
# Precision: 0.6427 | Recall: 0.6517 | F1 Score: 0.6382
#
# Epoch 26/50
# Train Loss: 0.8638 | Train Acc: 82.71%
# Val Loss: 1.2317 | Val Acc: 65.32%
# Precision: 0.6477 | Recall: 0.6571 | F1 Score: 0.6492
#
# Epoch 27/50
# Train Loss: 0.8243 | Train Acc: 84.91%
# Val Loss: 1.2746 | Val Acc: 64.25%
# Precision: 0.6329 | Recall: 0.6466 | F1 Score: 0.6365
#
# Epoch 28/50
# Train Loss: 0.7959 | Train Acc: 86.68%
# Val Loss: 1.2923 | Val Acc: 61.43%
# Precision: 0.6239 | Recall: 0.6183 | F1 Score: 0.6155
#
# Epoch 29/50
# Train Loss: 0.7642 | Train Acc: 88.39%
# Val Loss: 1.2175 | Val Acc: 66.34%
# Precision: 0.6608 | Recall: 0.6680 | F1 Score: 0.6608
#
# Epoch 30/50
# Train Loss: 0.7265 | Train Acc: 90.15%
# Val Loss: 1.3014 | Val Acc: 64.45%
# Precision: 0.6364 | Recall: 0.6508 | F1 Score: 0.6360
#
# Epoch 31/50
# Train Loss: 0.7248 | Train Acc: 90.21%
# Val Loss: 1.2087 | Val Acc: 67.93%
# Precision: 0.6757 | Recall: 0.6833 | F1 Score: 0.6775
#
# Epoch 32/50
# Train Loss: 0.6800 | Train Acc: 92.38%
# Val Loss: 1.2303 | Val Acc: 66.70%
# Precision: 0.6638 | Recall: 0.6713 | F1 Score: 0.6643
#
# Epoch 33/50
# Train Loss: 0.6625 | Train Acc: 93.23%
# Val Loss: 1.2016 | Val Acc: 68.75%
# Precision: 0.6842 | Recall: 0.6923 | F1 Score: 0.6861
#
# Epoch 34/50
# Train Loss: 0.6233 | Train Acc: 95.42%
# Val Loss: 1.2515 | Val Acc: 65.98%
# Precision: 0.6567 | Recall: 0.6656 | F1 Score: 0.6551
#
# Epoch 35/50
# Train Loss: 0.6003 | Train Acc: 96.16%
# Val Loss: 1.2557 | Val Acc: 66.85%
# Precision: 0.6649 | Recall: 0.6745 | F1 Score: 0.6630
#
# Epoch 36/50
# Train Loss: 0.5767 | Train Acc: 97.11%
# Val Loss: 1.2389 | Val Acc: 66.55%
# Precision: 0.6592 | Recall: 0.6710 | F1 Score: 0.6633
#
# Epoch 37/50
# Train Loss: 0.5780 | Train Acc: 96.82%
# Val Loss: 1.2199 | Val Acc: 67.77%
# Precision: 0.6697 | Recall: 0.6829 | F1 Score: 0.6732
#
# Epoch 38/50
# Train Loss: 0.5557 | Train Acc: 97.95%
# Val Loss: 1.2093 | Val Acc: 67.62%
# Precision: 0.6707 | Recall: 0.6818 | F1 Score: 0.6735
#
# Epoch 39/50
# Train Loss: 0.5350 | Train Acc: 98.64%
# Val Loss: 1.2001 | Val Acc: 68.44%
# Precision: 0.6755 | Recall: 0.6904 | F1 Score: 0.6793
#
# Epoch 40/50
# Train Loss: 0.5244 | Train Acc: 98.99%
# Val Loss: 1.1934 | Val Acc: 68.24%
# Precision: 0.6751 | Recall: 0.6885 | F1 Score: 0.6771
#
# Epoch 41/50
# Train Loss: 0.5168 | Train Acc: 99.19%
# Val Loss: 1.1974 | Val Acc: 68.13%
# Precision: 0.6773 | Recall: 0.6873 | F1 Score: 0.6771
#
# Epoch 42/50
# Train Loss: 0.5146 | Train Acc: 99.21%
# Val Loss: 1.1925 | Val Acc: 69.16%
# Precision: 0.6887 | Recall: 0.6970 | F1 Score: 0.6874
#
# Epoch 43/50
# Train Loss: 0.5041 | Train Acc: 99.44%
# Val Loss: 1.1811 | Val Acc: 68.59%
# Precision: 0.6815 | Recall: 0.6918 | F1 Score: 0.6811
#
# Epoch 44/50
# Train Loss: 0.4966 | Train Acc: 99.69%
# Val Loss: 1.1727 | Val Acc: 69.51%
# Precision: 0.6914 | Recall: 0.7003 | F1 Score: 0.6927
#
# Epoch 45/50
# Train Loss: 0.4929 | Train Acc: 99.80%
# Val Loss: 1.1738 | Val Acc: 69.21%
# Precision: 0.6861 | Recall: 0.6978 | F1 Score: 0.6880
#
# Epoch 46/50
# Train Loss: 0.4934 | Train Acc: 99.68%
# Val Loss: 1.1756 | Val Acc: 68.54%
# Precision: 0.6805 | Recall: 0.6910 | F1 Score: 0.6820
#
# Epoch 47/50
# Train Loss: 0.4915 | Train Acc: 99.69%
# Val Loss: 1.1900 | Val Acc: 68.34%
# Precision: 0.6836 | Recall: 0.6891 | F1 Score: 0.6788
#
# Epoch 48/50
# Train Loss: 0.4902 | Train Acc: 99.62%
# Val Loss: 1.1783 | Val Acc: 68.29%
# Precision: 0.6783 | Recall: 0.6886 | F1 Score: 0.6796
#
# Epoch 49/50
# Train Loss: 0.4873 | Train Acc: 99.77%
# Val Loss: 1.1621 | Val Acc: 69.26%
# Precision: 0.6877 | Recall: 0.6981 | F1 Score: 0.6892
#
# Epoch 50/50
# Train Loss: 0.4860 | Train Acc: 99.81%
# Val Loss: 1.1800 | Val Acc: 68.90%
# Precision: 0.6882 | Recall: 0.6946 | F1 Score: 0.6857
#
# ######## Training Finished in 95903.38510584831 seconds ###########

# %% [markdown]
# # Evaluating

# %%
model.eval() 

with torch.no_grad(): 
    correct = 0
    total = 0
    for data in test_loader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print(f'Test Accuracy of the model on the {total} test images: {(correct / total) * 100:.2f}%')
# Out:
# Test Accuracy of the model on the 1957 test images: 42.51%

# %%
def plot_training(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, len(train_losses) + 1)

    plt.figure(figsize=(12, 5))
    
    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.plot(epochs, val_losses, label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy')
    plt.plot(epochs, val_accuracies, label='Val Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Training and Validation Accuracy')
    plt.legend()

    plt.show()

plot_training(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
cm = conf_matrix.cpu().numpy()
disp = ConfusionMatrixDisplay(cm, display_labels=classes,)
disp.plot()

# %% [markdown]
# # Metrics

# %%
precision = MulticlassPrecision(num_classes=num_classes, average=None)
recall = MulticlassRecall(num_classes=num_classes, average=None)
f1_score = MulticlassF1Score(num_classes=num_classes, average=None)


all_preds = []
all_labels = []

model.eval()
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())


all_preds = torch.cat(all_preds)
all_labels = torch.cat(all_labels)


per_class_precision = precision(all_preds, all_labels)
per_class_recall = recall(all_preds, all_labels)
per_class_f1 = f1_score(all_preds, all_labels)


for i, name in enumerate(classes):
    print(f"Class {i}-{name}: Precision: {per_class_precision[i]:.2f}, Recall: {per_class_recall[i]:.2f}, F1-Score: {per_class_f1[i]:.2f}")
# Out:
# Class 0-Density1_Benign: Precision: 0.73, Recall: 0.64, F1-Score: 0.68
# Class 1-Density1_Malignant: Precision: 0.64, Recall: 0.58, F1-Score: 0.61
# Class 2-Density2_Benign: Precision: 0.59, Recall: 0.50, F1-Score: 0.55
# Class 3-Density2_Malignant: Precision: 0.45, Recall: 0.36, F1-Score: 0.40
# Class 4-Density3_Benign: Precision: 0.63, Recall: 0.94, F1-Score: 0.75
# Class 5-Density3_Malignant: Precision: 0.86, Recall: 0.88, F1-Score: 0.87
# Class 6-Density4_Benign: Precision: 0.70, Recall: 0.76, F1-Score: 0.73
# Class 7-Density4_Malignant: Precision: 0.90, Recall: 0.89, F1-Score: 0.90

# %% [markdown]
# # Save Model

# %%
torch.save(model.state_dict(), '/home/viviane/projects/breast-cancer-v2/models/model_alexnet.pt')
